# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkakakkar/LGMVIP-DataScience-Internship/blob/main/Iris_Flower_Classification_ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LetsGrowMore
# # Name : Anushka Kakkar
#
# # Task 01 :Iris Flower Classification
#
# # Level : Beginner level task

# %% [markdown]
# # Dataset Information
#
# The data set contains 3 classes of 50 instances each,where each class refers to a type of iris plant. One class is linearly separable from the other2; the latter are NOT linearly separable from each other
#
# Attribute Information
#
# 1.sepal lenght in cm
#
# 2.sepal width in cm
#
# 3.petal lenght in cm
#
# 4.petal width in cm
#
# class:--Iris Setosa--Iris Versicolour--Iris Verginica

# %% [markdown]
# # Import modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Loading the dataset

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e27e6f16-c0df-4df0-ada6-dabf6abc5d11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e27e6f16-c0df-4df0-ada6-dabf6abc5d11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv
# ...

# %%
data=pd.read_csv('Iris.csv')
print(data.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # Preprocessing the dataset

# %%
categorical =  ['Species']

def binary_map(x):
    return x.map({'Iris-setosa': 1, 'Iris-versicolor': 0 ,'Iris-virginica':2})

# now replace yes and no with 1 and 0 in our dataset
data[categorical] = data[categorical].apply(binary_map)

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        1
# 1   2            4.9           3.0            1.4           0.2        1
# 2   3            4.7           3.2            1.3           0.2        1
# 3   4            4.6           3.1            1.5           0.2        1
# 4   5            5.0           3.6            1.4           0.2        1

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2

# %%
data.shape
# Out:
# (150, 6)

# %%
data.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print(data.groupby('PetalLengthCm').size())
# Out:
# PetalLengthCm
# 1.0     1
# 1.1     1
# 1.2     2
# 1.3     7
# 1.4    12
# 1.5    14
# 1.6     7
# 1.7     4
# 1.9     2
# 3.0     1
# 3.3     2
# 3.5     2
# 3.6     1
# 3.7     1
# 3.8     1
# 3.9     3
# 4.0     5
# 4.1     3
# 4.2     4
# 4.3     2
# 4.4     4
# 4.5     8
# 4.6     3
# 4.7     5
# 4.8     4
# 4.9     5
# 5.0     4
# 5.1     8
# 5.2     2
# 5.3     2
# 5.4     2
# 5.5     3
# 5.6     6
# 5.7     3
# 5.8     3
# 5.9     2
# 6.0     2
# 6.1     3
# 6.3     1
# 6.4     1
# 6.6     1
# 6.7     2
# 6.9     1
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
import seaborn as sns
sns.countplot(data['PetalLengthCm'],label="count")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.groupby("PetalLengthCm").hist(figsize=(9,9))
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/tools.py:218: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)
# PetalLengthCm
# 1.0    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 1.1    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 1.2    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 1.3    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 1.4    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 1.5    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 1.6    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 1.7    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 1.9    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 3.0    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# ...

# %%
Iris_mod = data[(data.PetalWidthCm !=0)&(data.SepalLengthCm !=0)]
print(Iris_mod.shape)
# Out:
# (150, 6)

# %% [markdown]
# # Correlation Matrix

# %%
Iris_mod.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# Species        0.471415       0.322522      0.192719       0.299942
#
#                PetalWidthCm   Species
# Id                 0.899759  0.471415
# SepalLengthCm      0.817954  0.322522
# SepalWidthCm      -0.356544  0.192719
# PetalLengthCm      0.962757  0.299942
# PetalWidthCm       1.000000  0.375715
# Species            0.375715  1.000000

# %%
sns.heatmap(Iris_mod.corr())

# %%
plt.figure(figsize=(10,7))
corr_mat = Iris_mod.iloc[:,:-1].corr()
sns.heatmap(corr_mat, fmt='0.2f', annot=True, lw=2, cbar_kws={'label':'Pearson Correlation (r)'})
plt.xticks(size=15,rotation=90)
plt.yticks(size=15)
plt.tight_layout()
plt.savefig('Correlation.png',dpi=300);

# %%
plt.subplots(figsize=(20,15))
sns.boxplot(x='PetalWidthCm',y='SepalWidthCm',data=Iris_mod)

# %%
sns.pairplot(Iris_mod,hue='PetalLengthCm')

# %%
X = Iris_mod.iloc[:,:8]
X.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        1
# 1   2            4.9           3.0            1.4           0.2        1
# 2   3            4.7           3.2            1.3           0.2        1
# 3   4            4.6           3.1            1.5           0.2        1
# 4   5            5.0           3.6            1.4           0.2        1

# %%
y = Iris_mod["PetalLengthCm"]
y.head()
# Out:
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# Name: PetalLengthCm, dtype: float64

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data['Species'] = le.fit_transform(data['Species'])
data.head
# Out:
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        1
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        1
# 3      4            4.6           3.1            1.5           0.2        1
# 4      5            5.0           3.6            1.4           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]>

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
# train - 70
# test - 30
X = data.drop(columns=['Species'])
Y= data['Species']
x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size=0.30)

# %%
# Logistic regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
# print metrix to get performance
print("Accuracy: ",model.score(x_test, y_test)*100)
# Out:
# Accuracy:  100.0

# %%
# knn - k-nearest neighbors
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# print metrix to get performance
print("Accuracy: ",model.score(x_train, y_train)*100)
# Out:
# Accuracy:  100.0

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# print metrix to get performance
print("Accuracy: ",model.score(x_test, y_test)*100)
# Out:
# Accuracy:  97.77777777777777
